# %%
import pandas as pd

# %%
bh = pd.read_csv('barts_hotspots.csv')
bh
# barts station also a hot pick up area
# Out:
#             Date  Origin Movement ID  \
# 0     06/09/2019                3396
# 1     04/28/2019                3603
# 2     05/18/2019                3603
# 3     04/18/2019                3792
# 4     04/08/2019                3792
# ...          ...                 ...
# 3253  01/06/2019                3396
# 3254  01/24/2019                3396
# 3255  01/09/2019                3760
# 3256  02/04/2019                3760
# 3257  03/04/2019                3760
#
#                                     Origin Display Name  \
# 0     The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 1                        Embarcadero, San Francisco, CA
# 2                        Embarcadero, San Francisco, CA
# 3     Oracle Park, 24 Willie Mays Plaza, San Francis...
# 4     Oracle Park, 24 Willie Mays Plaza, San Francis...
# ...                                                 ...
# 3253  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3254  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3255  Powell BART Station, Market St and Powell St, ...
# 3256  Powell BART Station, Market St and Powell St, ...
# 3257  Powell BART Station, Market St and Powell St, ...
#
#       Destination Movement ID  \
# 0                        3603
# 1                        3394
# 2                        3394
# 3                        3603
# 4                        3603
# ...                       ...
# 3253                     3760
# 3254                     3760
# 3255                     3792
# 3256                     3396
# 3257                     3394
#
#                                Destination Display Name  \
# 0                        Embarcadero, San Francisco, CA
# 1                  Fisherman's Wharf, San Francisco, CA
# 2                  Fisherman's Wharf, San Francisco, CA
# 3                        Embarcadero, San Francisco, CA
# 4                        Embarcadero, San Francisco, CA
# ...                                                 ...
# 3253  Powell BART Station, Market St and Powell St, ...
# 3254  Powell BART Station, Market St and Powell St, ...
# 3255  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 3256  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3257               Fisherman's Wharf, San Francisco, CA
#
#       Daily Mean Travel Time (Seconds)  \
# 0                               1588.0
# 1                                639.0
# 2                                730.0
# 3                                512.0
# 4                                505.0
# ...                                ...
# 3253                               NaN
# 3254                            1586.0
# 3255                             795.0
# 3256                               NaN
# 3257                             869.0
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 0                                              1054.0
# 1                                               512.0
# 2                                               520.0
# 3                                               371.0
# 4                                               364.0
# ...                                               ...
# 3253                                              NaN
# 3254                                           1203.0
# 3255                                            548.0
# 3256                                              NaN
# 3257                                            634.0
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 0                                              2392.0
# 1                                               796.0
# 2                                              1024.0
# 3                                               705.0
# 4                                               701.0
# ...                                               ...
# 3253                                              NaN
# 3254                                           2091.0
# 3255                                           1155.0
# 3256                                              NaN
# 3257                                           1190.0
#
#       AM Mean Travel Time (Seconds)  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                             648.0
# 4                             621.0
# ...                             ...
# 3253                            NaN
# 3254                         1580.0
# 3255                          760.0
# 3256                            NaN
# 3257                          891.0
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 0                                              NaN  ...
# 1                                              NaN  ...
# 2                                              NaN  ...
# 3                                            461.0  ...
# 4                                            489.0  ...
# ...                                            ...  ...
# 3253                                           NaN  ...
# 3254                                        1240.0  ...
# 3255                                         536.0  ...
# 3256                                           NaN  ...
# 3257                                         724.0  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 0                                              NaN
# 1                                            793.0
# 2                                            985.0
# 3                                            720.0
# 4                                            941.0
# ...                                            ...
# 3253                                           NaN
# 3254                                           NaN
# 3255                                           NaN
# 3256                                           NaN
# 3257                                        1256.0
#
#       Midday Mean Travel Time (Seconds)  \
# 0                                   NaN
# 1                                 654.0
# 2                                 791.0
# 3                                 528.0
# 4                                 429.0
# ...                                 ...
# 3253                                NaN
# 3254                                NaN
# 3255                              951.0
# 3256                                NaN
# 3257                              782.0
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 0                                                  NaN
# 1                                                524.0
# 2                                                590.0
# 3                                                398.0
# 4                                                339.0
# ...                                                ...
# 3253                                               NaN
# 3254                                               NaN
# 3255                                             556.0
# 3256                                               NaN
# 3257                                             603.0
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 0                                                  NaN
# 1                                                817.0
# 2                                               1061.0
# 3                                                702.0
# 4                                                542.0
# ...                                                ...
# 3253                                               NaN
# 3254                                               NaN
# 3255                                            1624.0
# 3256                                               NaN
# 3257                                            1015.0
#
#       Evening Mean Travel Time (Seconds)  \
# 0                                    NaN
# 1                                  608.0
# 2                                  569.0
# 3                                  442.0
# 4                                  502.0
# ...                                  ...
# 3253                                 NaN
# 3254                                 NaN
# 3255                               806.0
# 3256                                 NaN
# 3257                               885.0
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 1                                                 492.0
# 2                                                 406.0
# 3                                                 321.0
# 4                                                 354.0
# ...                                                 ...
# 3253                                                NaN
# 3254                                                NaN
# 3255                                              597.0
# 3256                                                NaN
# 3257                                              627.0
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 1                                                 753.0
# 2                                                 797.0
# 3                                                 608.0
# 4                                                 711.0
# ...                                                 ...
# 3253                                                NaN
# 3254                                                NaN
# 3255                                             1088.0
# 3256                                                NaN
# 3257                                             1249.0
#
#       Early Morning Mean Travel Time (Seconds)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                        363.0
# 4                                          NaN
# ...                                        ...
# 3253                                       NaN
# 3254                                       NaN
# 3255                                       NaN
# 3256                                       NaN
# 3257                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                 297.0
# 4                                                   NaN
# ...                                                 ...
# 3253                                                NaN
# 3254                                                NaN
# 3255                                                NaN
# 3256                                                NaN
# 3257                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                 443.0
# 4                                                   NaN
# ...                                                 ...
# 3253                                                NaN
# 3254                                                NaN
# 3255                                                NaN
# 3256                                                NaN
# 3257                                                NaN
#
# [3258 rows x 23 columns]

# %%
ba = pd.read_csv('barts_to_all.csv')
ba
# bars station where pick up take place
# Out:
#        Origin Movement ID                                Origin Display Name  \
# 0                    3603                     Embarcadero, San Francisco, CA
# 1                    3603                     Embarcadero, San Francisco, CA
# 2                    3603                     Embarcadero, San Francisco, CA
# 3                    3603                     Embarcadero, San Francisco, CA
# 4                    3603                     Embarcadero, San Francisco, CA
# ...                   ...                                                ...
# 10868                3760  Powell BART Station, Market St and Powell St, ...
# 10869                3760  Powell BART Station, Market St and Powell St, ...
# 10870                3760  Powell BART Station, Market St and Powell St, ...
# 10871                3760  Powell BART Station, Market St and Powell St, ...
# 10872                3760  Powell BART Station, Market St and Powell St, ...
#
#        Destination Movement ID Destination Display Name  \
# 0                         1987            709716 (1987)
# 1                         1994            910502 (1994)
# 2                         2020            609301 (2020)
# 3                         2044            609270 (2044)
# 4                         2054            609261 (2054)
# ...                        ...                      ...
# 10868                     6793            303543 (6793)
# 10869                     6806            303551 (6806)
# 10870                     6821            303562 (6821)
# 10871                     6835            303403 (6835)
# 10872                     6837            303392 (6837)
#
#                                            Date Range  \
# 0      4/1/2019 - 6/30/2019, Every day, Daily Average
# 1      4/1/2019 - 6/30/2019, Every day, Daily Average
# 2      4/1/2019 - 6/30/2019, Every day, Daily Average
# 3      4/1/2019 - 6/30/2019, Every day, Daily Average
# 4      4/1/2019 - 6/30/2019, Every day, Daily Average
# ...                                               ...
# 10868  1/1/2019 - 3/31/2019, Every day, Daily Average
# 10869  1/1/2019 - 3/31/2019, Every day, Daily Average
# 10870  1/1/2019 - 3/31/2019, Every day, Daily Average
# 10871  1/1/2019 - 3/31/2019, Every day, Daily Average
# 10872  1/1/2019 - 3/31/2019, Every day, Daily Average
#
#        Mean Travel Time (Seconds)  Range - Lower Bound Travel Time (Seconds)  \
# 0                            3373                                       2479
# 1                            2888                                       2486
# 2                            3015                                       2173
# 3                            3019                                       2156
# 4                            2916                                       2079
# ...                           ...                                        ...
# 10868                        3561                                       2862
# 10869                        3604                                       2891
# 10870                        3630                                       2927
# 10871                        3621                                       2959
# 10872                        3715                                       3011
#
#        Range - Upper Bound Travel Time (Seconds)
# 0                                           4589
# 1                                           3353
# 2                                           4182
# 3                                           4226
# 4                                           4089
# ...                                          ...
# 10868                                       4430
# 10869                                       4492
# 10870                                       4501
# 10871                                       4431
# 10872                                       4582
#
# [10873 rows x 8 columns]

# %%
ha = pd.read_csv('hotspots_to_all.csv')
ha
#hot area for pick ups
# Out:
#       Origin Movement ID                                Origin Display Name  \
# 0                   3394               Fisherman's Wharf, San Francisco, CA
# 1                   3394               Fisherman's Wharf, San Francisco, CA
# 2                   3394               Fisherman's Wharf, San Francisco, CA
# 3                   3394               Fisherman's Wharf, San Francisco, CA
# 4                   3394               Fisherman's Wharf, San Francisco, CA
# ...                  ...                                                ...
# 7816                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7817                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7818                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7819                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7820                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#       Destination Movement ID Destination Display Name  \
# 0                        1608            709746 (1608)
# 1                        1803            809911 (1803)
# 2                        1845            910670 (1845)
# 3                        1864            709739 (1864)
# 4                        1866            809914 (1866)
# ...                       ...                      ...
# 7816                     5888            20226A (5888)
# 7817                     5891            202258 (5891)
# 7818                     5894            302443 (5894)
# 7819                     5931            202251 (5931)
# 7820                     5957            302520 (5957)
#
#                                           Date Range  \
# 0     4/1/2019 - 6/30/2019, Every day, Daily Average
# 1     4/1/2019 - 6/30/2019, Every day, Daily Average
# 2     4/1/2019 - 6/30/2019, Every day, Daily Average
# 3     4/1/2019 - 6/30/2019, Every day, Daily Average
# 4     4/1/2019 - 6/30/2019, Every day, Daily Average
# ...                                              ...
# 7816  1/1/2019 - 3/31/2019, Every day, Daily Average
# 7817  1/1/2019 - 3/31/2019, Every day, Daily Average
# 7818  1/1/2019 - 3/31/2019, Every day, Daily Average
# 7819  1/1/2019 - 3/31/2019, Every day, Daily Average
# 7820  1/1/2019 - 3/31/2019, Every day, Daily Average
#
#       Mean Travel Time (Seconds)  Range - Lower Bound Travel Time (Seconds)  \
# 0                           4030                                       3244
# 1                           3782                                       3110
# 2                           2412                                       2133
# 3                           4453                                       3546
# 4                           3592                                       2884
# ...                          ...                                        ...
# 7816                        3235                                       2693
# 7817                        3158                                       2632
# 7818                        3293                                       2714
# 7819                        3182                                       2624
# 7820                        3320                                       2768
#
#       Range - Upper Bound Travel Time (Seconds)
# 0                                          5005
# 1                                          4599
# 2                                          2726
# 3                                          5590
# 4                                          4472
# ...                                         ...
# 7816                                       3886
# 7817                                       3788
# 7818                                       3994
# 7819                                       3857
# 7820                                       3981
#
# [7821 rows x 8 columns]

# %%
h1 = pd.read_csv('hours_q1.csv')
h1
# Out:
#         sourceid  dstid  hod  mean_travel_time  \
# 0           3768   3700    3            161.58
# 1           3772   3660    3            373.98
# 2           3751   3708    6           1197.27
# 3           3761   3608    6            588.32
# 4           3767   3724   17            438.98
# ...          ...    ...  ...               ...
# 633167      3393   3390   23            592.03
# 633168      3395   3399   20           1113.72
# 633169      3399   3398    9           1145.57
# 633170      3391   3398    4             97.24
# 633171      3390   3393   21            664.02
#
#         standard_deviation_travel_time  geometric_mean_travel_time  \
# 0                                87.83                      147.02
# 1                               217.24                      328.16
# 2                               259.18                     1171.36
# 3                               223.30                      557.92
# 4                               235.70                      395.22
# ...                                ...                         ...
# 633167                          290.07                      529.47
# 633168                          340.11                     1066.33
# 633169                          424.05                     1073.19
# 633170                           69.76                       75.26
# 633171                          279.16                      613.86
#
#         geometric_standard_deviation_travel_time
# 0                                           1.49
# 1                                           1.65
# 2                                           1.23
# 3                                           1.36
# 4                                           1.55
# ...                                          ...
# 633167                                      1.59
# 633168                                      1.34
# 633169                                      1.43
# 633170                                      2.05
# 633171                                      1.47
#
# [633172 rows x 7 columns]

# %%
h1 = pd.read_csv('hours_q2.csv')
h1
# Out:
#         sourceid  dstid  hod  mean_travel_time  \
# 0           3709   3671   13            875.06
# 1           3708   3681   13            850.12
# 2           3632   3715    8           1017.34
# 3           3642   3615    8             94.17
# 4           3643   3605    8            171.74
# ...          ...    ...  ...               ...
# 635560      3395   3391   16            454.32
# 635561      3394   3393   17           2666.26
# 635562      3393   3395   18            311.48
# 635563      3398   3391   15            153.51
# 635564      3390   3393    8            756.88
#
#         standard_deviation_travel_time  geometric_mean_travel_time  \
# 0                               232.37                      850.74
# 1                               224.94                      826.64
# 2                               298.82                      973.40
# 3                                75.18                       71.61
# 4                               205.52                      112.04
# ...                                ...                         ...
# 635560                          322.86                      406.18
# 635561                          671.32                     2583.85
# 635562                          180.95                      279.77
# 635563                          122.92                      120.83
# 635564                          304.25                      704.46
#
#         geometric_standard_deviation_travel_time
# 0                                           1.25
# 1                                           1.25
# 2                                           1.35
# 3                                           2.17
# 4                                           2.41
# ...                                          ...
# 635560                                      1.54
# 635561                                      1.29
# 635562                                      1.52
# 635563                                      1.98
# 635564                                      1.45
#
# [635565 rows x 7 columns]

# %%
#TAZ traffic analysis zone
#For every Hotspot, recommend the appropriate BART station to get off of in order to **minimize travel time**.

# %%
ha
# Out:
#       Origin Movement ID                                Origin Display Name  \
# 0                   3394               Fisherman's Wharf, San Francisco, CA
# 1                   3394               Fisherman's Wharf, San Francisco, CA
# 2                   3394               Fisherman's Wharf, San Francisco, CA
# 3                   3394               Fisherman's Wharf, San Francisco, CA
# 4                   3394               Fisherman's Wharf, San Francisco, CA
# ...                  ...                                                ...
# 7816                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7817                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7818                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7819                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 7820                3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#       Destination Movement ID Destination Display Name  \
# 0                        1608            709746 (1608)
# 1                        1803            809911 (1803)
# 2                        1845            910670 (1845)
# 3                        1864            709739 (1864)
# 4                        1866            809914 (1866)
# ...                       ...                      ...
# 7816                     5888            20226A (5888)
# 7817                     5891            202258 (5891)
# 7818                     5894            302443 (5894)
# 7819                     5931            202251 (5931)
# 7820                     5957            302520 (5957)
#
#                                           Date Range  \
# 0     4/1/2019 - 6/30/2019, Every day, Daily Average
# 1     4/1/2019 - 6/30/2019, Every day, Daily Average
# 2     4/1/2019 - 6/30/2019, Every day, Daily Average
# 3     4/1/2019 - 6/30/2019, Every day, Daily Average
# 4     4/1/2019 - 6/30/2019, Every day, Daily Average
# ...                                              ...
# 7816  1/1/2019 - 3/31/2019, Every day, Daily Average
# 7817  1/1/2019 - 3/31/2019, Every day, Daily Average
# 7818  1/1/2019 - 3/31/2019, Every day, Daily Average
# 7819  1/1/2019 - 3/31/2019, Every day, Daily Average
# 7820  1/1/2019 - 3/31/2019, Every day, Daily Average
#
#       Mean Travel Time (Seconds)  Range - Lower Bound Travel Time (Seconds)  \
# 0                           4030                                       3244
# 1                           3782                                       3110
# 2                           2412                                       2133
# 3                           4453                                       3546
# 4                           3592                                       2884
# ...                          ...                                        ...
# 7816                        3235                                       2693
# 7817                        3158                                       2632
# 7818                        3293                                       2714
# 7819                        3182                                       2624
# 7820                        3320                                       2768
#
#       Range - Upper Bound Travel Time (Seconds)
# 0                                          5005
# 1                                          4599
# 2                                          2726
# 3                                          5590
# 4                                          4472
# ...                                         ...
# 7816                                       3886
# 7817                                       3788
# 7818                                       3994
# 7819                                       3857
# 7820                                       3981
#
# [7821 rows x 8 columns]

# %%
#Step1:ha
hotposts = ha['Origin Movement ID'].unique()
# Out:
# array([3394, 3792, 3396])

# %%
barts = ba['Origin Movement ID'].unique()
# Out:
# array([3603, 3692, 3760])

# %%
ba['Origin Display Name'].unique()
# Out:
# array(['Embarcadero, San Francisco, CA',
#        '2nd Street and Stevenson Street (Montgomery BART, San Francisco, CA',
#        'Powell BART Station, Market St and Powell St, San Francisco, CA'],
#       dtype=object)

# %%
bh['Origin Movement ID'].unique()
# Out:
# array([3396, 3603, 3792, 3394, 3692, 3760])

# %%
bh['Destination Movement ID'].unique()
# Out:
# array([3603, 3394, 3396, 3792, 3692, 3760])

# %%
ha['Destination Display Name'].unique()
# Out:
# array(['709746 (1608)', '809911 (1803)', '910670 (1845)', ...,
#        '304104 (6506)', '303590 (6887)', '910853 (2817)'], dtype=object)

# %%
bh_hotspots_3394 = bh[(bh['Origin Movement ID'] == 3394)|(bh['Destination Movement ID'] == 3394)]
bh_hotspots_3394
# Out:
#             Date  Origin Movement ID  \
# 1     04/28/2019                3603
# 2     05/18/2019                3603
# 6     04/23/2019                3603
# 7     05/13/2019                3603
# 8     05/15/2019                3394
# ...          ...                 ...
# 3243  01/18/2019                3760
# 3247  02/13/2019                3760
# 3250  03/18/2019                3760
# 3252  03/13/2019                3394
# 3257  03/04/2019                3760
#
#                                     Origin Display Name  \
# 1                        Embarcadero, San Francisco, CA
# 2                        Embarcadero, San Francisco, CA
# 6                        Embarcadero, San Francisco, CA
# 7                        Embarcadero, San Francisco, CA
# 8                  Fisherman's Wharf, San Francisco, CA
# ...                                                 ...
# 3243  Powell BART Station, Market St and Powell St, ...
# 3247  Powell BART Station, Market St and Powell St, ...
# 3250  Powell BART Station, Market St and Powell St, ...
# 3252               Fisherman's Wharf, San Francisco, CA
# 3257  Powell BART Station, Market St and Powell St, ...
#
#       Destination Movement ID  \
# 1                        3394
# 2                        3394
# 6                        3394
# 7                        3394
# 8                        3603
# ...                       ...
# 3243                     3394
# 3247                     3394
# 3250                     3394
# 3252                     3760
# 3257                     3394
#
#                                Destination Display Name  \
# 1                  Fisherman's Wharf, San Francisco, CA
# 2                  Fisherman's Wharf, San Francisco, CA
# 6                  Fisherman's Wharf, San Francisco, CA
# 7                  Fisherman's Wharf, San Francisco, CA
# 8                        Embarcadero, San Francisco, CA
# ...                                                 ...
# 3243               Fisherman's Wharf, San Francisco, CA
# 3247               Fisherman's Wharf, San Francisco, CA
# 3250               Fisherman's Wharf, San Francisco, CA
# 3252  Powell BART Station, Market St and Powell St, ...
# 3257               Fisherman's Wharf, San Francisco, CA
#
#       Daily Mean Travel Time (Seconds)  \
# 1                                639.0
# 2                                730.0
# 6                                682.0
# 7                                634.0
# 8                                878.0
# ...                                ...
# 3243                             933.0
# 3247                             956.0
# 3250                             916.0
# 3252                            1038.0
# 3257                             869.0
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 1                                               512.0
# 2                                               520.0
# 6                                               500.0
# 7                                               457.0
# 8                                               621.0
# ...                                               ...
# 3243                                            693.0
# 3247                                            637.0
# 3250                                            674.0
# 3252                                            784.0
# 3257                                            634.0
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 1                                               796.0
# 2                                              1024.0
# 6                                               931.0
# 7                                               878.0
# 8                                              1243.0
# ...                                               ...
# 3243                                           1256.0
# 3247                                           1435.0
# 3250                                           1246.0
# 3252                                           1375.0
# 3257                                           1190.0
#
#       AM Mean Travel Time (Seconds)  \
# 1                               NaN
# 2                               NaN
# 6                               NaN
# 7                               NaN
# 8                             904.0
# ...                             ...
# 3243                            NaN
# 3247                            NaN
# 3250                          943.0
# 3252                         1129.0
# 3257                          891.0
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 1                                              NaN  ...
# 2                                              NaN  ...
# 6                                              NaN  ...
# 7                                              NaN  ...
# 8                                            650.0  ...
# ...                                            ...  ...
# 3243                                           NaN  ...
# 3247                                           NaN  ...
# 3250                                         775.0  ...
# 3252                                         867.0  ...
# 3257                                         724.0  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 1                                            793.0
# 2                                            985.0
# 6                                            949.0
# 7                                            893.0
# 8                                           1549.0
# ...                                            ...
# 3243                                        1586.0
# 3247                                        1953.0
# 3250                                        1386.0
# 3252                                        1408.0
# 3257                                        1256.0
#
#       Midday Mean Travel Time (Seconds)  \
# 1                                 654.0
# 2                                 791.0
# 6                                 756.0
# 7                                 584.0
# 8                                 732.0
# ...                                 ...
# 3243                              849.0
# 3247                              812.0
# 3250                              865.0
# 3252                             1143.0
# 3257                              782.0
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 1                                                524.0
# 2                                                590.0
# 6                                                577.0
# 7                                                470.0
# 8                                                586.0
# ...                                                ...
# 3243                                             654.0
# 3247                                             601.0
# 3250                                             649.0
# 3252                                             875.0
# 3257                                             603.0
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 1                                                817.0
# 2                                               1061.0
# 6                                                991.0
# 7                                                726.0
# 8                                                915.0
# ...                                                ...
# 3243                                            1102.0
# 3247                                            1097.0
# 3250                                            1154.0
# 3252                                            1493.0
# 3257                                            1015.0
#
#       Evening Mean Travel Time (Seconds)  \
# 1                                  608.0
# 2                                  569.0
# 6                                  550.0
# 7                                  611.0
# 8                                  795.0
# ...                                  ...
# 3243                               819.0
# 3247                               893.0
# 3250                               885.0
# 3252                               942.0
# 3257                               885.0
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 1                                                 492.0
# 2                                                 406.0
# 6                                                 406.0
# 7                                                 424.0
# 8                                                 612.0
# ...                                                 ...
# 3243                                              665.0
# 3247                                              611.0
# 3250                                              639.0
# 3252                                              727.0
# 3257                                              627.0
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 1                                                 753.0
# 2                                                 797.0
# 6                                                 745.0
# 7                                                 880.0
# 8                                                1032.0
# ...                                                 ...
# 3243                                             1009.0
# 3247                                             1305.0
# 3250                                             1227.0
# 3252                                             1221.0
# 3257                                             1249.0
#
#       Early Morning Mean Travel Time (Seconds)  \
# 1                                          NaN
# 2                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                        568.0
# ...                                        ...
# 3243                                       NaN
# 3247                                       NaN
# 3250                                       NaN
# 3252                                       NaN
# 3257                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 1                                                   NaN
# 2                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                 438.0
# ...                                                 ...
# 3243                                                NaN
# 3247                                                NaN
# 3250                                                NaN
# 3252                                                NaN
# 3257                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 1                                                   NaN
# 2                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                 736.0
# ...                                                 ...
# 3243                                                NaN
# 3247                                                NaN
# 3250                                                NaN
# 3252                                                NaN
# 3257                                                NaN
#
# [1086 rows x 23 columns]

# %%
bh_hotspots_3792 = bh[(bh['Origin Movement ID'] == 3792)|(bh['Destination Movement ID'] == 3792)]
bh_hotspots_3792
# Out:
#             Date  Origin Movement ID  \
# 3     04/18/2019                3792
# 4     04/08/2019                3792
# 5     06/30/2019                3792
# 11    04/18/2019                3603
# 12    06/11/2019                3792
# ...          ...                 ...
# 3244  03/25/2019                3792
# 3245  02/22/2019                3792
# 3248  02/21/2019                3792
# 3251  03/20/2019                3792
# 3255  01/09/2019                3760
#
#                                     Origin Display Name  \
# 3     Oracle Park, 24 Willie Mays Plaza, San Francis...
# 4     Oracle Park, 24 Willie Mays Plaza, San Francis...
# 5     Oracle Park, 24 Willie Mays Plaza, San Francis...
# 11                       Embarcadero, San Francisco, CA
# 12    Oracle Park, 24 Willie Mays Plaza, San Francis...
# ...                                                 ...
# 3244  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 3245  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 3248  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 3251  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 3255  Powell BART Station, Market St and Powell St, ...
#
#       Destination Movement ID  \
# 3                        3603
# 4                        3603
# 5                        3603
# 11                       3792
# 12                       3603
# ...                       ...
# 3244                     3760
# 3245                     3760
# 3248                     3760
# 3251                     3760
# 3255                     3792
#
#                                Destination Display Name  \
# 3                        Embarcadero, San Francisco, CA
# 4                        Embarcadero, San Francisco, CA
# 5                        Embarcadero, San Francisco, CA
# 11    Oracle Park, 24 Willie Mays Plaza, San Francis...
# 12                       Embarcadero, San Francisco, CA
# ...                                                 ...
# 3244  Powell BART Station, Market St and Powell St, ...
# 3245  Powell BART Station, Market St and Powell St, ...
# 3248  Powell BART Station, Market St and Powell St, ...
# 3251  Powell BART Station, Market St and Powell St, ...
# 3255  Oracle Park, 24 Willie Mays Plaza, San Francis...
#
#       Daily Mean Travel Time (Seconds)  \
# 3                                512.0
# 4                                505.0
# 5                                616.0
# 11                               591.0
# 12                               643.0
# ...                                ...
# 3244                             877.0
# 3245                             910.0
# 3248                            1029.0
# 3251                            1086.0
# 3255                             795.0
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 3                                               371.0
# 4                                               364.0
# 5                                               385.0
# 11                                              417.0
# 12                                              451.0
# ...                                               ...
# 3244                                            573.0
# 3245                                            597.0
# 3248                                            656.0
# 3251                                            669.0
# 3255                                            548.0
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 3                                               705.0
# 4                                               701.0
# 5                                               987.0
# 11                                              837.0
# 12                                              916.0
# ...                                               ...
# 3244                                           1342.0
# 3245                                           1386.0
# 3248                                           1614.0
# 3251                                           1763.0
# 3255                                           1155.0
#
#       AM Mean Travel Time (Seconds)  \
# 3                             648.0
# 4                             621.0
# 5                               NaN
# 11                            650.0
# 12                            814.0
# ...                             ...
# 3244                            NaN
# 3245                            NaN
# 3248                            NaN
# 3251                            NaN
# 3255                          760.0
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 3                                            461.0  ...
# 4                                            489.0  ...
# 5                                              NaN  ...
# 11                                           462.0  ...
# 12                                           646.0  ...
# ...                                            ...  ...
# 3244                                           NaN  ...
# 3245                                           NaN  ...
# 3248                                           NaN  ...
# 3251                                           NaN  ...
# 3255                                         536.0  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 3                                            720.0
# 4                                            941.0
# 5                                           1017.0
# 11                                          1035.0
# 12                                          1180.0
# ...                                            ...
# 3244                                        1584.0
# 3245                                           NaN
# 3248                                        2016.0
# 3251                                        1689.0
# 3255                                           NaN
#
#       Midday Mean Travel Time (Seconds)  \
# 3                                 528.0
# 4                                 429.0
# 5                                   NaN
# 11                                614.0
# 12                                595.0
# ...                                 ...
# 3244                              957.0
# 3245                              921.0
# 3248                             1008.0
# 3251                                NaN
# 3255                              951.0
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 3                                                398.0
# 4                                                339.0
# 5                                                  NaN
# 11                                               456.0
# 12                                               433.0
# ...                                                ...
# 3244                                             622.0
# 3245                                             628.0
# 3248                                             722.0
# 3251                                               NaN
# 3255                                             556.0
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 3                                                702.0
# 4                                                542.0
# 5                                                  NaN
# 11                                               828.0
# 12                                               816.0
# ...                                                ...
# 3244                                            1472.0
# 3245                                            1350.0
# 3248                                            1407.0
# 3251                                               NaN
# 3255                                            1624.0
#
#       Evening Mean Travel Time (Seconds)  \
# 3                                  442.0
# 4                                  502.0
# 5                                  386.0
# 11                                 496.0
# 12                                 463.0
# ...                                  ...
# 3244                               748.0
# 3245                               881.0
# 3248                               678.0
# 3251                               867.0
# 3255                               806.0
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 3                                                 321.0
# 4                                                 354.0
# 5                                                 276.0
# 11                                                357.0
# 12                                                366.0
# ...                                                 ...
# 3244                                              520.0
# 3245                                              517.0
# 3248                                              532.0
# 3251                                              593.0
# 3255                                              597.0
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 3                                                 608.0
# 4                                                 711.0
# 5                                                 541.0
# 11                                                688.0
# 12                                                585.0
# ...                                                 ...
# 3244                                             1078.0
# 3245                                             1502.0
# 3248                                              864.0
# 3251                                             1266.0
# 3255                                             1088.0
#
#       Early Morning Mean Travel Time (Seconds)  \
# 3                                        363.0
# 4                                          NaN
# 5                                          NaN
# 11                                       417.0
# 12                                       449.0
# ...                                        ...
# 3244                                       NaN
# 3245                                       NaN
# 3248                                       NaN
# 3251                                       NaN
# 3255                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 3                                                 297.0
# 4                                                   NaN
# 5                                                   NaN
# 11                                                331.0
# 12                                                371.0
# ...                                                 ...
# 3244                                                NaN
# 3245                                                NaN
# 3248                                                NaN
# 3251                                                NaN
# 3255                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 3                                                 443.0
# 4                                                   NaN
# 5                                                   NaN
# 11                                                525.0
# 12                                                542.0
# ...                                                 ...
# 3244                                                NaN
# 3245                                                NaN
# 3248                                                NaN
# 3251                                                NaN
# 3255                                                NaN
#
# [1086 rows x 23 columns]

# %%
bh_hotspots_3396 = bh[(bh['Origin Movement ID'] == 3396)|(bh['Destination Movement ID'] == 3396)]
bh_hotspots_3396
# Out:
#             Date  Origin Movement ID  \
# 0     06/09/2019                3396
# 9     04/14/2019                3603
# 15    06/06/2019                3396
# 16    04/18/2019                3396
# 18    06/11/2019                3396
# ...          ...                 ...
# 3246  02/26/2019                3760
# 3249  02/18/2019                3396
# 3253  01/06/2019                3396
# 3254  01/24/2019                3396
# 3256  02/04/2019                3760
#
#                                     Origin Display Name  \
# 0     The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 9                        Embarcadero, San Francisco, CA
# 15    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 16    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 18    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# ...                                                 ...
# 3246  Powell BART Station, Market St and Powell St, ...
# 3249  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3253  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3254  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3256  Powell BART Station, Market St and Powell St, ...
#
#       Destination Movement ID  \
# 0                        3603
# 9                        3396
# 15                       3603
# 16                       3603
# 18                       3603
# ...                       ...
# 3246                     3396
# 3249                     3760
# 3253                     3760
# 3254                     3760
# 3256                     3396
#
#                                Destination Display Name  \
# 0                        Embarcadero, San Francisco, CA
# 9     The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 15                       Embarcadero, San Francisco, CA
# 16                       Embarcadero, San Francisco, CA
# 18                       Embarcadero, San Francisco, CA
# ...                                                 ...
# 3246  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3249  Powell BART Station, Market St and Powell St, ...
# 3253  Powell BART Station, Market St and Powell St, ...
# 3254  Powell BART Station, Market St and Powell St, ...
# 3256  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#       Daily Mean Travel Time (Seconds)  \
# 0                               1588.0
# 9                                996.0
# 15                              1363.0
# 16                              1313.0
# 18                              1438.0
# ...                                ...
# 3246                            1462.0
# 3249                            1279.0
# 3253                               NaN
# 3254                            1586.0
# 3256                               NaN
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 0                                              1054.0
# 9                                               853.0
# 15                                             1166.0
# 16                                              964.0
# 18                                             1060.0
# ...                                               ...
# 3246                                           1056.0
# 3249                                           1046.0
# 3253                                              NaN
# 3254                                           1203.0
# 3256                                              NaN
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 0                                              2392.0
# 9                                              1164.0
# 15                                             1595.0
# 16                                             1789.0
# 18                                             1951.0
# ...                                               ...
# 3246                                           2023.0
# 3249                                           1563.0
# 3253                                              NaN
# 3254                                           2091.0
# 3256                                              NaN
#
#       AM Mean Travel Time (Seconds)  \
# 0                               NaN
# 9                               NaN
# 15                           1327.0
# 16                           1489.0
# 18                           1259.0
# ...                             ...
# 3246                            NaN
# 3249                            NaN
# 3253                            NaN
# 3254                         1580.0
# 3256                            NaN
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 0                                              NaN  ...
# 9                                              NaN  ...
# 15                                          1164.0  ...
# 16                                          1051.0  ...
# 18                                          1102.0  ...
# ...                                            ...  ...
# 3246                                           NaN  ...
# 3249                                           NaN  ...
# 3253                                           NaN  ...
# 3254                                        1240.0  ...
# 3256                                           NaN  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 0                                              NaN
# 9                                              NaN
# 15                                          1698.0
# 16                                             NaN
# 18                                          2612.0
# ...                                            ...
# 3246                                        2314.0
# 3249                                           NaN
# 3253                                           NaN
# 3254                                           NaN
# 3256                                           NaN
#
#       Midday Mean Travel Time (Seconds)  \
# 0                                   NaN
# 9                                1063.0
# 15                               1370.0
# 16                               1393.0
# 18                                  NaN
# ...                                 ...
# 3246                                NaN
# 3249                                NaN
# 3253                                NaN
# 3254                                NaN
# 3256                                NaN
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 0                                                  NaN
# 9                                                928.0
# 15                                              1151.0
# 16                                              1123.0
# 18                                                 NaN
# ...                                                ...
# 3246                                               NaN
# 3249                                               NaN
# 3253                                               NaN
# 3254                                               NaN
# 3256                                               NaN
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 0                                                  NaN
# 9                                               1219.0
# 15                                              1631.0
# 16                                              1727.0
# 18                                                 NaN
# ...                                                ...
# 3246                                               NaN
# 3249                                               NaN
# 3253                                               NaN
# 3254                                               NaN
# 3256                                               NaN
#
#       Evening Mean Travel Time (Seconds)  \
# 0                                    NaN
# 9                                    NaN
# 15                                   NaN
# 16                                   NaN
# 18                                   NaN
# ...                                  ...
# 3246                                 NaN
# 3249                                 NaN
# 3253                                 NaN
# 3254                                 NaN
# 3256                                 NaN
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 9                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# ...                                                 ...
# 3246                                                NaN
# 3249                                                NaN
# 3253                                                NaN
# 3254                                                NaN
# 3256                                                NaN
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 9                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# ...                                                 ...
# 3246                                                NaN
# 3249                                                NaN
# 3253                                                NaN
# 3254                                                NaN
# 3256                                                NaN
#
#       Early Morning Mean Travel Time (Seconds)  \
# 0                                          NaN
# 9                                          NaN
# 15                                         NaN
# 16                                         NaN
# 18                                         NaN
# ...                                        ...
# 3246                                       NaN
# 3249                                       NaN
# 3253                                       NaN
# 3254                                       NaN
# 3256                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 9                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# ...                                                 ...
# 3246                                                NaN
# 3249                                                NaN
# 3253                                                NaN
# 3254                                                NaN
# 3256                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 0                                                   NaN
# 9                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# ...                                                 ...
# 3246                                                NaN
# 3249                                                NaN
# 3253                                                NaN
# 3254                                                NaN
# 3256                                                NaN
#
# [1086 rows x 23 columns]

# %%
bh_hotspots_3396['Daily Mean Travel Time (Minutes)'] = bh_hotspots_3396['Daily Mean Travel Time (Seconds)']/60
bh_hotspots_3396['AM Mean Travel Time (Minutes)'] = bh_hotspots_3396['AM Mean Travel Time (Seconds)']/60
bh_hotspots_3396['PM Mean Travel Time (Minutes)'] = bh_hotspots_3396['PM Mean Travel Time (Seconds)']/60
bh_hotspots_3396['Midday Mean Travel Time (Minutes)'] = bh_hotspots_3396['Midday Mean Travel Time (Seconds)']/60
bh_hotspots_3396['Evening Mean Travel Time (Minutes)'] = bh_hotspots_3396['Evening Mean Travel Time (Seconds)']/60
bh_hotspots_3396['Early Morning Mean Travel Time (Minutes)'] = bh_hotspots_3396['Early Morning Mean Travel Time (Seconds)']/60
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
a = bh_hotspots_3396.boxplot(column=['Daily Mean Travel Time (Seconds)',
       #'Daily Range - Lower Bound Travel Time (Seconds)',
       #'Daily Range - Upper Bound Travel Time (Seconds)',
       'AM Mean Travel Time (Seconds)',
       #'AM Range - Lower Bound Travel Time (Seconds)',
       #'AM Range - Upper Bound Travel Time (Seconds)',
       'PM Mean Travel Time (Seconds)',
       #'PM Range - Lower Bound Travel Time (Seconds)',
       #'PM Range - Upper Bound Travel Time (Seconds)',
       'Midday Mean Travel Time (Seconds)',
       #'Midday Range - Lower Bound Travel Time (Seconds)',
       #'Midday Range - Upper Bound Travel Time (Seconds)',
       'Evening Mean Travel Time (Seconds)',
       #'Evening Range - Lower Bound Travel Time (Seconds)',
       #'Evening Range - Upper Bound Travel Time (Seconds)',
       'Early Morning Mean Travel Time (Seconds)',
       #'Early Morning Range - Lower Bound Travel Time (Seconds)',
       #'Early Morning Range - Upper Bound Travel Time (Seconds)']
                                    ],figsize = (10,8),rot=90)
# we looked at data for each timeframe

# %%
def barts_hopspot_time_match(h1_TAZ, TAZ):
    #h1_TAZ = h1[(h1['Destination Movement ID'] == TAZ)|(h1['Origin Movement ID'] == TAZ)]
    #h1[h1['Origin Movement ID'] != TAZ]
    b =h1_TAZ[h1_TAZ['Destination Movement ID'] == TAZ]
    a = h1_TAZ[h1_TAZ['Destination Movement ID'] != TAZ]
    display(a)
    display(b)
    b['Destination Movement ID'] = b['Origin Movement ID']
    b['Origin Movement ID'] = [TAZ]*len(b)
    c = pd.concat([a,b],join = 'outer',axis = 0)
    return c

# %%
bh_hotspots_3396 = barts_hopspot_time_match(bh_hotspots_3396, 3396)
bh_hotspots_3396
# Out:
#             Date  Origin Movement ID  \
# 0     06/09/2019                3396
# 15    06/06/2019                3396
# 16    04/18/2019                3396
# 18    06/11/2019                3396
# 30    05/03/2019                3396
# ...          ...                 ...
# 3238  01/11/2019                3396
# 3241  01/25/2019                3396
# 3249  02/18/2019                3396
# 3253  01/06/2019                3396
# 3254  01/24/2019                3396
#
#                                     Origin Display Name  \
# 0     The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 15    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 16    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 18    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 30    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# ...                                                 ...
# 3238  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3241  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3249  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3253  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3254  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#       Destination Movement ID  \
# 0                        3603
# 15                       3603
# 16                       3603
# 18                       3603
# 30                       3603
# ...                       ...
# 3238                     3760
# 3241                     3760
# 3249                     3760
# 3253                     3760
# 3254                     3760
#
#                                Destination Display Name  \
# 0                        Embarcadero, San Francisco, CA
# 15                       Embarcadero, San Francisco, CA
# 16                       Embarcadero, San Francisco, CA
# 18                       Embarcadero, San Francisco, CA
# 30                       Embarcadero, San Francisco, CA
# ...                                                 ...
# 3238  Powell BART Station, Market St and Powell St, ...
# 3241  Powell BART Station, Market St and Powell St, ...
# 3249  Powell BART Station, Market St and Powell St, ...
# 3253  Powell BART Station, Market St and Powell St, ...
# 3254  Powell BART Station, Market St and Powell St, ...
#
#       Daily Mean Travel Time (Seconds)  \
# 0                               1588.0
# 15                              1363.0
# 16                              1313.0
# 18                              1438.0
# 30                              1214.0
# ...                                ...
# 3238                            1529.0
# 3241                            1536.0
# 3249                            1279.0
# 3253                               NaN
# 3254                            1586.0
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 0                                              1054.0
# 15                                             1166.0
# 16                                              964.0
# 18                                             1060.0
# 30                                              990.0
# ...                                               ...
# 3238                                           1144.0
# 3241                                           1237.0
# 3249                                           1046.0
# 3253                                              NaN
# 3254                                           1203.0
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 0                                              2392.0
# 15                                             1595.0
# 16                                             1789.0
# 18                                             1951.0
# 30                                             1488.0
# ...                                               ...
# 3238                                           2043.0
# 3241                                           1907.0
# 3249                                           1563.0
# 3253                                              NaN
# 3254                                           2091.0
#
#       AM Mean Travel Time (Seconds)  \
# 0                               NaN
# 15                           1327.0
# 16                           1489.0
# 18                           1259.0
# 30                           1152.0
# ...                             ...
# 3238                         1395.0
# 3241                         1571.0
# 3249                            NaN
# 3253                            NaN
# 3254                         1580.0
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 0                                              NaN  ...
# 15                                          1164.0  ...
# 16                                          1051.0  ...
# 18                                          1102.0  ...
# 30                                           962.0  ...
# ...                                            ...  ...
# 3238                                        1181.0  ...
# 3241                                        1323.0  ...
# 3249                                           NaN  ...
# 3253                                           NaN  ...
# 3254                                        1240.0  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 0                                              NaN
# 15                                          1698.0
# 16                                             NaN
# 18                                          2612.0
# 30                                          1557.0
# ...                                            ...
# 3238                                        2551.0
# 3241                                           NaN
# 3249                                           NaN
# 3253                                           NaN
# 3254                                           NaN
#
#       Midday Mean Travel Time (Seconds)  \
# 0                                   NaN
# 15                               1370.0
# 16                               1393.0
# 18                                  NaN
# 30                               1187.0
# ...                                 ...
# 3238                             1489.0
# 3241                             1336.0
# 3249                                NaN
# 3253                                NaN
# 3254                                NaN
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 0                                                  NaN
# 15                                              1151.0
# 16                                              1123.0
# 18                                                 NaN
# 30                                               985.0
# ...                                                ...
# 3238                                            1114.0
# 3241                                            1133.0
# 3249                                               NaN
# 3253                                               NaN
# 3254                                               NaN
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 0                                                  NaN
# 15                                              1631.0
# 16                                              1727.0
# 18                                                 NaN
# 30                                              1432.0
# ...                                                ...
# 3238                                            1990.0
# 3241                                            1574.0
# 3249                                               NaN
# 3253                                               NaN
# 3254                                               NaN
#
#       Evening Mean Travel Time (Seconds)  \
# 0                                    NaN
# 15                                   NaN
# 16                                   NaN
# 18                                   NaN
# 30                                   NaN
# ...                                  ...
# 3238                                 NaN
# 3241                                 NaN
# 3249                                 NaN
# 3253                                 NaN
# 3254                                 NaN
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3238                                                NaN
# 3241                                                NaN
# 3249                                                NaN
# 3253                                                NaN
# 3254                                                NaN
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3238                                                NaN
# 3241                                                NaN
# 3249                                                NaN
# 3253                                                NaN
# 3254                                                NaN
#
#       Early Morning Mean Travel Time (Seconds)  \
# 0                                          NaN
# 15                                         NaN
# 16                                         NaN
# 18                                         NaN
# 30                                         NaN
# ...                                        ...
# 3238                                       NaN
# 3241                                       NaN
# 3249                                       NaN
# 3253                                       NaN
# 3254                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3238                                                NaN
# 3241                                                NaN
# 3249                                                NaN
# 3253                                                NaN
# 3254                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3238                                                NaN
# 3241                                                NaN
# 3249                                                NaN
# 3253                                                NaN
# 3254                                                NaN
#
# [543 rows x 23 columns]
#             Date  Origin Movement ID  \
# 9     04/14/2019                3603
# 29    05/30/2019                3603
# 32    06/03/2019                3603
# 35    05/27/2019                3603
# 39    04/21/2019                3603
# ...          ...                 ...
# 3229  01/12/2019                3760
# 3232  03/30/2019                3760
# 3240  03/13/2019                3760
# 3246  02/26/2019                3760
# 3256  02/04/2019                3760
#
#                                     Origin Display Name  \
# 9                        Embarcadero, San Francisco, CA
# 29                       Embarcadero, San Francisco, CA
# 32                       Embarcadero, San Francisco, CA
# 35                       Embarcadero, San Francisco, CA
# 39                       Embarcadero, San Francisco, CA
# ...                                                 ...
# 3229  Powell BART Station, Market St and Powell St, ...
# 3232  Powell BART Station, Market St and Powell St, ...
# 3240  Powell BART Station, Market St and Powell St, ...
# 3246  Powell BART Station, Market St and Powell St, ...
# 3256  Powell BART Station, Market St and Powell St, ...
#
#       Destination Movement ID  \
# 9                        3396
# 29                       3396
# 32                       3396
# 35                       3396
# 39                       3396
# ...                       ...
# 3229                     3396
# 3232                     3396
# 3240                     3396
# 3246                     3396
# 3256                     3396
#
#                                Destination Display Name  \
# 9     The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 29    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 32    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 35    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 39    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# ...                                                 ...
# 3229  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3232  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3240  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3246  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3256  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#       Daily Mean Travel Time (Seconds)  \
# 9                                996.0
# 29                              1112.0
# 32                              1220.0
# 35                              1066.0
# 39                              1331.0
# ...                                ...
# 3229                            1333.0
# 3232                             969.0
# 3240                            1546.0
# 3246                            1462.0
# 3256                               NaN
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 9                                               853.0
# 29                                              768.0
# 32                                             1011.0
# 35                                              901.0
# 39                                             1094.0
# ...                                               ...
# 3229                                           1052.0
# 3232                                            788.0
# 3240                                           1035.0
# 3246                                           1056.0
# 3256                                              NaN
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 9                                              1164.0
# 29                                             1608.0
# 32                                             1473.0
# 35                                             1262.0
# 39                                             1619.0
# ...                                               ...
# 3229                                           1687.0
# 3232                                           1191.0
# 3240                                           2311.0
# 3246                                           2023.0
# 3256                                              NaN
#
#       AM Mean Travel Time (Seconds)  \
# 9                               NaN
# 29                            845.0
# 32                              NaN
# 35                              NaN
# 39                              NaN
# ...                             ...
# 3229                            NaN
# 3232                            NaN
# 3240                            NaN
# 3246                            NaN
# 3256                            NaN
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 9                                              NaN  ...
# 29                                           474.0  ...
# 32                                             NaN  ...
# 35                                             NaN  ...
# 39                                             NaN  ...
# ...                                            ...  ...
# 3229                                           NaN  ...
# 3232                                           NaN  ...
# 3240                                           NaN  ...
# 3246                                           NaN  ...
# 3256                                           NaN  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 9                                              NaN
# 29                                          1607.0
# 32                                          1525.0
# 35                                             NaN
# 39                                             NaN
# ...                                            ...
# 3229                                           NaN
# 3232                                           NaN
# 3240                                           NaN
# 3246                                        2314.0
# 3256                                           NaN
#
#       Midday Mean Travel Time (Seconds)  \
# 9                                1063.0
# 29                               1191.0
# 32                               1195.0
# 35                               1115.0
# 39                               1333.0
# ...                                 ...
# 3229                             1405.0
# 3232                                NaN
# 3240                                NaN
# 3246                                NaN
# 3256                                NaN
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 9                                                928.0
# 29                                              1000.0
# 32                                              1040.0
# 35                                               977.0
# 39                                              1058.0
# ...                                                ...
# 3229                                            1144.0
# 3232                                               NaN
# 3240                                               NaN
# 3246                                               NaN
# 3256                                               NaN
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 9                                               1219.0
# 29                                              1419.0
# 32                                              1373.0
# 35                                              1272.0
# 39                                              1679.0
# ...                                                ...
# 3229                                            1725.0
# 3232                                               NaN
# 3240                                               NaN
# 3246                                               NaN
# 3256                                               NaN
#
#       Evening Mean Travel Time (Seconds)  \
# 9                                    NaN
# 29                                 970.0
# 32                                   NaN
# 35                                   NaN
# 39                                   NaN
# ...                                  ...
# 3229                                 NaN
# 3232                                 NaN
# 3240                                 NaN
# 3246                                 NaN
# 3256                                 NaN
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 9                                                   NaN
# 29                                                793.0
# 32                                                  NaN
# 35                                                  NaN
# 39                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 9                                                   NaN
# 29                                               1188.0
# 32                                                  NaN
# 35                                                  NaN
# 39                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
#       Early Morning Mean Travel Time (Seconds)  \
# 9                                          NaN
# 29                                         NaN
# 32                                         NaN
# 35                                         NaN
# 39                                         NaN
# ...                                        ...
# 3229                                       NaN
# 3232                                       NaN
# 3240                                       NaN
# 3246                                       NaN
# 3256                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 9                                                   NaN
# 29                                                  NaN
# 32                                                  NaN
# 35                                                  NaN
# 39                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 9                                                   NaN
# 29                                                  NaN
# 32                                                  NaN
# 35                                                  NaN
# 39                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
# [543 rows x 23 columns]
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#             Date  Origin Movement ID  \
# 0     06/09/2019                3396
# 15    06/06/2019                3396
# 16    04/18/2019                3396
# 18    06/11/2019                3396
# 30    05/03/2019                3396
# ...          ...                 ...
# 3229  01/12/2019                3396
# 3232  03/30/2019                3396
# 3240  03/13/2019                3396
# 3246  02/26/2019                3396
# 3256  02/04/2019                3396
#
#                                     Origin Display Name  \
# 0     The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 15    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 16    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 18    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 30    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# ...                                                 ...
# 3229  Powell BART Station, Market St and Powell St, ...
# 3232  Powell BART Station, Market St and Powell St, ...
# 3240  Powell BART Station, Market St and Powell St, ...
# 3246  Powell BART Station, Market St and Powell St, ...
# 3256  Powell BART Station, Market St and Powell St, ...
#
#       Destination Movement ID  \
# 0                        3603
# 15                       3603
# 16                       3603
# 18                       3603
# 30                       3603
# ...                       ...
# 3229                     3760
# 3232                     3760
# 3240                     3760
# 3246                     3760
# 3256                     3760
#
#                                Destination Display Name  \
# 0                        Embarcadero, San Francisco, CA
# 15                       Embarcadero, San Francisco, CA
# 16                       Embarcadero, San Francisco, CA
# 18                       Embarcadero, San Francisco, CA
# 30                       Embarcadero, San Francisco, CA
# ...                                                 ...
# 3229  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3232  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3240  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3246  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3256  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#       Daily Mean Travel Time (Seconds)  \
# 0                               1588.0
# 15                              1363.0
# 16                              1313.0
# 18                              1438.0
# 30                              1214.0
# ...                                ...
# 3229                            1333.0
# 3232                             969.0
# 3240                            1546.0
# 3246                            1462.0
# 3256                               NaN
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 0                                              1054.0
# 15                                             1166.0
# 16                                              964.0
# 18                                             1060.0
# 30                                              990.0
# ...                                               ...
# 3229                                           1052.0
# 3232                                            788.0
# 3240                                           1035.0
# 3246                                           1056.0
# 3256                                              NaN
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 0                                              2392.0
# 15                                             1595.0
# 16                                             1789.0
# 18                                             1951.0
# 30                                             1488.0
# ...                                               ...
# 3229                                           1687.0
# 3232                                           1191.0
# 3240                                           2311.0
# 3246                                           2023.0
# 3256                                              NaN
#
#       AM Mean Travel Time (Seconds)  \
# 0                               NaN
# 15                           1327.0
# 16                           1489.0
# 18                           1259.0
# 30                           1152.0
# ...                             ...
# 3229                            NaN
# 3232                            NaN
# 3240                            NaN
# 3246                            NaN
# 3256                            NaN
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 0                                              NaN  ...
# 15                                          1164.0  ...
# 16                                          1051.0  ...
# 18                                          1102.0  ...
# 30                                           962.0  ...
# ...                                            ...  ...
# 3229                                           NaN  ...
# 3232                                           NaN  ...
# 3240                                           NaN  ...
# 3246                                           NaN  ...
# 3256                                           NaN  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 0                                              NaN
# 15                                          1698.0
# 16                                             NaN
# 18                                          2612.0
# 30                                          1557.0
# ...                                            ...
# 3229                                           NaN
# 3232                                           NaN
# 3240                                           NaN
# 3246                                        2314.0
# 3256                                           NaN
#
#       Midday Mean Travel Time (Seconds)  \
# 0                                   NaN
# 15                               1370.0
# 16                               1393.0
# 18                                  NaN
# 30                               1187.0
# ...                                 ...
# 3229                             1405.0
# 3232                                NaN
# 3240                                NaN
# 3246                                NaN
# 3256                                NaN
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 0                                                  NaN
# 15                                              1151.0
# 16                                              1123.0
# 18                                                 NaN
# 30                                               985.0
# ...                                                ...
# 3229                                            1144.0
# 3232                                               NaN
# 3240                                               NaN
# 3246                                               NaN
# 3256                                               NaN
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 0                                                  NaN
# 15                                              1631.0
# 16                                              1727.0
# 18                                                 NaN
# 30                                              1432.0
# ...                                                ...
# 3229                                            1725.0
# 3232                                               NaN
# 3240                                               NaN
# 3246                                               NaN
# 3256                                               NaN
#
#       Evening Mean Travel Time (Seconds)  \
# 0                                    NaN
# 15                                   NaN
# 16                                   NaN
# 18                                   NaN
# 30                                   NaN
# ...                                  ...
# 3229                                 NaN
# 3232                                 NaN
# 3240                                 NaN
# 3246                                 NaN
# 3256                                 NaN
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
#       Early Morning Mean Travel Time (Seconds)  \
# 0                                          NaN
# 15                                         NaN
# 16                                         NaN
# 18                                         NaN
# 30                                         NaN
# ...                                        ...
# 3229                                       NaN
# 3232                                       NaN
# 3240                                       NaN
# 3246                                       NaN
# 3256                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
# [1086 rows x 23 columns]

# %%
bh_hotspots_3396 = barts_hopspot_time_match(bh_hotspots_3396, 3396)
#bh_hotspots_3396_3692 = barts_hopspot_time_match(bh_hotspots_3396, 3692)
#bh_hotspots_3396_3760 = barts_hopspot_time_match(bh_hotspots_3396, 3760)
bh_hotspots_3792 = barts_hopspot_time_match(bh_hotspots_3792, 3792)
#bh_hotspots_3792_3692 = barts_hopspot_time_match(bh_hotspots_3792, 3692)
#bh_hotspots_3792_3760 = barts_hopspot_time_match(bh_hotspots_3792, 3760)
bh_hotspots_3394 = barts_hopspot_time_match(bh_hotspots_3394, 3394)
#bh_hotspots_3394_3692 = barts_hopspot_time_match(bh_hotspots_3394, 3692)
#bh_hotspots_3394_3760 = barts_hopspot_time_match(bh_hotspots_3394, 3760)
# Out:
#             Date  Origin Movement ID  \
# 0     06/09/2019              3396.0
# 15    06/06/2019              3396.0
# 16    04/18/2019              3396.0
# 18    06/11/2019              3396.0
# 30    05/03/2019              3396.0
# ...          ...                 ...
# 3229  01/12/2019              3396.0
# 3232  03/30/2019              3396.0
# 3240  03/13/2019              3396.0
# 3246  02/26/2019              3396.0
# 3256  02/04/2019              3396.0
#
#                                     Origin Display Name  \
# 0     The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 15    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 16    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 18    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 30    The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# ...                                                 ...
# 3229  Powell BART Station, Market St and Powell St, ...
# 3232  Powell BART Station, Market St and Powell St, ...
# 3240  Powell BART Station, Market St and Powell St, ...
# 3246  Powell BART Station, Market St and Powell St, ...
# 3256  Powell BART Station, Market St and Powell St, ...
#
#       Destination Movement ID  \
# 0                        3603
# 15                       3603
# 16                       3603
# 18                       3603
# 30                       3603
# ...                       ...
# 3229                     3760
# 3232                     3760
# 3240                     3760
# 3246                     3760
# 3256                     3760
#
#                                Destination Display Name  \
# 0                        Embarcadero, San Francisco, CA
# 15                       Embarcadero, San Francisco, CA
# 16                       Embarcadero, San Francisco, CA
# 18                       Embarcadero, San Francisco, CA
# 30                       Embarcadero, San Francisco, CA
# ...                                                 ...
# 3229  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3232  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3240  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3246  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3256  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#       Daily Mean Travel Time (Seconds)  \
# 0                               1588.0
# 15                              1363.0
# 16                              1313.0
# 18                              1438.0
# 30                              1214.0
# ...                                ...
# 3229                            1333.0
# 3232                             969.0
# 3240                            1546.0
# 3246                            1462.0
# 3256                               NaN
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 0                                              1054.0
# 15                                             1166.0
# 16                                              964.0
# 18                                             1060.0
# 30                                              990.0
# ...                                               ...
# 3229                                           1052.0
# 3232                                            788.0
# 3240                                           1035.0
# 3246                                           1056.0
# 3256                                              NaN
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 0                                              2392.0
# 15                                             1595.0
# 16                                             1789.0
# 18                                             1951.0
# 30                                             1488.0
# ...                                               ...
# 3229                                           1687.0
# 3232                                           1191.0
# 3240                                           2311.0
# 3246                                           2023.0
# 3256                                              NaN
#
#       AM Mean Travel Time (Seconds)  \
# 0                               NaN
# 15                           1327.0
# 16                           1489.0
# 18                           1259.0
# 30                           1152.0
# ...                             ...
# 3229                            NaN
# 3232                            NaN
# 3240                            NaN
# 3246                            NaN
# 3256                            NaN
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 0                                              NaN  ...
# 15                                          1164.0  ...
# 16                                          1051.0  ...
# 18                                          1102.0  ...
# 30                                           962.0  ...
# ...                                            ...  ...
# 3229                                           NaN  ...
# 3232                                           NaN  ...
# 3240                                           NaN  ...
# 3246                                           NaN  ...
# 3256                                           NaN  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 0                                              NaN
# 15                                          1698.0
# 16                                             NaN
# 18                                          2612.0
# 30                                          1557.0
# ...                                            ...
# 3229                                           NaN
# 3232                                           NaN
# 3240                                           NaN
# 3246                                        2314.0
# 3256                                           NaN
#
#       Midday Mean Travel Time (Seconds)  \
# 0                                   NaN
# 15                               1370.0
# 16                               1393.0
# 18                                  NaN
# 30                               1187.0
# ...                                 ...
# 3229                             1405.0
# 3232                                NaN
# 3240                                NaN
# 3246                                NaN
# 3256                                NaN
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 0                                                  NaN
# 15                                              1151.0
# 16                                              1123.0
# 18                                                 NaN
# 30                                               985.0
# ...                                                ...
# 3229                                            1144.0
# 3232                                               NaN
# 3240                                               NaN
# 3246                                               NaN
# 3256                                               NaN
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 0                                                  NaN
# 15                                              1631.0
# 16                                              1727.0
# 18                                                 NaN
# 30                                              1432.0
# ...                                                ...
# 3229                                            1725.0
# 3232                                               NaN
# 3240                                               NaN
# 3246                                               NaN
# 3256                                               NaN
#
#       Evening Mean Travel Time (Seconds)  \
# 0                                    NaN
# 15                                   NaN
# 16                                   NaN
# 18                                   NaN
# 30                                   NaN
# ...                                  ...
# 3229                                 NaN
# 3232                                 NaN
# 3240                                 NaN
# 3246                                 NaN
# 3256                                 NaN
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
#       Early Morning Mean Travel Time (Seconds)  \
# 0                                          NaN
# 15                                         NaN
# 16                                         NaN
# 18                                         NaN
# 30                                         NaN
# ...                                        ...
# 3229                                       NaN
# 3232                                       NaN
# 3240                                       NaN
# 3246                                       NaN
# 3256                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 0                                                   NaN
# 15                                                  NaN
# 16                                                  NaN
# 18                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 3229                                                NaN
# 3232                                                NaN
# 3240                                                NaN
# 3246                                                NaN
# 3256                                                NaN
#
# [1086 rows x 23 columns]
# Empty DataFrame
# Columns: [Date, Origin Movement ID, Origin Display Name, Destination Movement ID, Destination Display Name, Daily Mean Travel Time (Seconds), Daily Range - Lower Bound Travel Time (Seconds), Daily Range - Upper Bound Travel Time (Seconds), AM Mean Travel Time (Seconds), AM Range - Lower Bound Travel Time (Seconds), AM Range - Upper Bound Travel Time (Seconds), PM Mean Travel Time (Seconds), PM Range - Lower Bound Travel Time (Seconds), PM Range - Upper Bound Travel Time (Seconds), Midday Mean Travel Time (Seconds), Midday Range - Lower Bound Travel Time (Seconds), Midday Range - Upper Bound Travel Time (Seconds), Evening Mean Travel Time (Seconds), Evening Range - Lower Bound Travel Time (Seconds), Evening Range - Upper Bound Travel Time (Seconds), Early Morning Mean Travel Time (Seconds), Early Morning Range - Lower Bound Travel Time (Seconds), Early Morning Range - Upper Bound Travel Time (Seconds)]
# Index: []
#
# [0 rows x 23 columns]
#             Date  Origin Movement ID  \
# 546   05/28/2019                3792
# 547   06/28/2019                3792
# 550   04/16/2019                3792
# 552   06/15/2019                3792
# 555   05/21/2019                3792
# ...          ...                 ...
# 3239  03/21/2019                3792
# 3244  03/25/2019                3792
# 3245  02/22/2019                3792
# 3248  02/21/2019                3792
# 3251  03/20/2019                3792
#
#                                     Origin Display Name  \
# 546   Oracle Park, 24 Willie Mays Plaza, San Francis...
# 547   Oracle Park, 24 Willie Mays Plaza, San Francis...
# 550   Oracle Park, 24 Willie Mays Plaza, San Francis...
# 552   Oracle Park, 24 Willie Mays Plaza, San Francis...
# 555   Oracle Park, 24 Willie Mays Plaza, San Francis...
# ...                                                 ...
# 3239  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 3244  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 3245  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 3248  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 3251  Oracle Park, 24 Willie Mays Plaza, San Francis...
#
#       Destination Movement ID  \
# 546                      3692
# 547                      3692
# 550                      3692
# 552                      3692
# 555                      3692
# ...                       ...
# 3239                     3760
# 3244                     3760
# 3245                     3760
# 3248                     3760
# 3251                     3760
#
#                                Destination Display Name  \
# 546   2nd Street and Stevenson Street (Montgomery BA...
# 547   2nd Street and Stevenson Street (Montgomery BA...
# 550   2nd Street and Stevenson Street (Montgomery BA...
# 552   2nd Street and Stevenson Street (Montgomery BA...
# 555   2nd Street and Stevenson Street (Montgomery BA...
# ...                                                 ...
# 3239  Powell BART Station, Market St and Powell St, ...
# 3244  Powell BART Station, Market St and Powell St, ...
# 3245  Powell BART Station, Market St and Powell St, ...
# 3248  Powell BART Station, Market St and Powell St, ...
# 3251  Powell BART Station, Market St and Powell St, ...
#
#       Daily Mean Travel Time (Seconds)  \
# 546                              555.0
# 547                              670.0
# 550                              503.0
# 552                              554.0
# 555                              585.0
# ...                                ...
# 3239                             871.0
# 3244                             877.0
# 3245                             910.0
# 3248                            1029.0
# 3251                            1086.0
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 546                                             380.0
# 547                                             422.0
# 550                                             341.0
# 552                                             359.0
# 555                                             379.0
# ...                                               ...
# 3239                                            609.0
# 3244                                            573.0
# 3245                                            597.0
# 3248                                            656.0
# 3251                                            669.0
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 546                                             810.0
# 547                                            1063.0
# 550                                             741.0
# 552                                             857.0
# 555                                             903.0
# ...                                               ...
# 3239                                           1245.0
# 3244                                           1342.0
# 3245                                           1386.0
# 3248                                           1614.0
# 3251                                           1763.0
#
#       AM Mean Travel Time (Seconds)  \
# 546                           588.0
# 547                           663.0
# 550                           497.0
# 552                           452.0
# 555                           925.0
# ...                             ...
# 3239                            NaN
# 3244                            NaN
# 3245                            NaN
# 3248                            NaN
# 3251                            NaN
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 546                                          410.0  ...
# 547                                          452.0  ...
# 550                                          324.0  ...
# 552                                          311.0  ...
# 555                                          624.0  ...
# ...                                            ...  ...
# 3239                                           NaN  ...
# 3244                                           NaN  ...
# 3245                                           NaN  ...
# 3248                                           NaN  ...
# 3251                                           NaN  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 546                                          984.0
# 547                                         1209.0
# 550                                          832.0
# 552                                          938.0
# 555                                          977.0
# ...                                            ...
# 3239                                        1602.0
# 3244                                        1584.0
# 3245                                           NaN
# 3248                                        2016.0
# 3251                                        1689.0
#
#       Midday Mean Travel Time (Seconds)  \
# 546                               507.0
# 547                               681.0
# 550                               468.0
# 552                               616.0
# 555                               534.0
# ...                                 ...
# 3239                                NaN
# 3244                              957.0
# 3245                              921.0
# 3248                             1008.0
# 3251                                NaN
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 546                                              341.0
# 547                                              436.0
# 550                                              324.0
# 552                                              409.0
# 555                                              389.0
# ...                                                ...
# 3239                                               NaN
# 3244                                             622.0
# 3245                                             628.0
# 3248                                             722.0
# 3251                                               NaN
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 546                                              755.0
# 547                                             1065.0
# 550                                              675.0
# 552                                              927.0
# 555                                              732.0
# ...                                                ...
# 3239                                               NaN
# 3244                                            1472.0
# 3245                                            1350.0
# 3248                                            1407.0
# 3251                                               NaN
#
#       Evening Mean Travel Time (Seconds)  \
# 546                                490.0
# 547                                592.0
# 550                                472.0
# 552                                446.0
# 555                                458.0
# ...                                  ...
# 3239                               769.0
# 3244                               748.0
# 3245                               881.0
# 3248                               678.0
# 3251                               867.0
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 546                                               367.0
# 547                                               402.0
# 550                                               323.0
# 552                                               332.0
# 555                                               309.0
# ...                                                 ...
# 3239                                              561.0
# 3244                                              520.0
# 3245                                              517.0
# 3248                                              532.0
# 3251                                              593.0
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 546                                               653.0
# 547                                               871.0
# 550                                               689.0
# 552                                               598.0
# 555                                               679.0
# ...                                                 ...
# 3239                                             1053.0
# 3244                                             1078.0
# 3245                                             1502.0
# 3248                                              864.0
# 3251                                             1266.0
#
#       Early Morning Mean Travel Time (Seconds)  \
# 546                                        NaN
# 547                                      360.0
# 550                                        NaN
# 552                                      466.0
# 555                                      439.0
# ...                                        ...
# 3239                                       NaN
# 3244                                       NaN
# 3245                                       NaN
# 3248                                       NaN
# 3251                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 546                                                 NaN
# 547                                               220.0
# 550                                                 NaN
# 552                                               266.0
# 555                                               345.0
# ...                                                 ...
# 3239                                                NaN
# 3244                                                NaN
# 3245                                                NaN
# 3248                                                NaN
# 3251                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 546                                                 NaN
# 547                                               588.0
# 550                                                 NaN
# 552                                               819.0
# 555                                               558.0
# ...                                                 ...
# 3239                                                NaN
# 3244                                                NaN
# 3245                                                NaN
# 3248                                                NaN
# 3251                                                NaN
#
# [362 rows x 23 columns]
#             Date  Origin Movement ID  \
# 11    04/18/2019                3603
# 14    04/21/2019                3603
# 17    05/16/2019                3603
# 21    04/27/2019                3603
# 25    06/21/2019                3603
# ...          ...                 ...
# 2158  01/04/2019                3603
# 2169  03/02/2019                3603
# 2172  01/23/2019                3603
# 2173  01/24/2019                3603
# 2175  02/09/2019                3603
#
#                                     Origin Display Name  \
# 11                       Embarcadero, San Francisco, CA
# 14                       Embarcadero, San Francisco, CA
# 17                       Embarcadero, San Francisco, CA
# 21                       Embarcadero, San Francisco, CA
# 25                       Embarcadero, San Francisco, CA
# ...                                                 ...
# 2158  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 2169  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 2172  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 2173  Oracle Park, 24 Willie Mays Plaza, San Francis...
# 2175  Oracle Park, 24 Willie Mays Plaza, San Francis...
#
#       Destination Movement ID  \
# 11                       3792
# 14                       3792
# 17                       3792
# 21                       3792
# 25                       3792
# ...                       ...
# 2158                     3792
# 2169                     3792
# 2172                     3792
# 2173                     3792
# 2175                     3792
#
#                                Destination Display Name  \
# 11    Oracle Park, 24 Willie Mays Plaza, San Francis...
# 14    Oracle Park, 24 Willie Mays Plaza, San Francis...
# 17    Oracle Park, 24 Willie Mays Plaza, San Francis...
# 21    Oracle Park, 24 Willie Mays Plaza, San Francis...
# 25    Oracle Park, 24 Willie Mays Plaza, San Francis...
# ...                                                 ...
# 2158                     Embarcadero, San Francisco, CA
# 2169                     Embarcadero, San Francisco, CA
# 2172                     Embarcadero, San Francisco, CA
# 2173                     Embarcadero, San Francisco, CA
# 2175                     Embarcadero, San Francisco, CA
#
#       Daily Mean Travel Time (Seconds)  \
# 11                               591.0
# 14                               469.0
# 17                               605.0
# 21                               510.0
# 25                               565.0
# ...                                ...
# 2158                             425.0
# 2169                             671.0
# 2172                             546.0
# 2173                             567.0
# 2175                             457.0
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 11                                              417.0
# 14                                              332.0
# 17                                              434.0
# 21                                              359.0
# 25                                              403.0
# ...                                               ...
# 2158                                            328.0
# 2169                                            457.0
# 2172                                            392.0
# 2173                                            403.0
# 2175                                            344.0
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 11                                              837.0
# 14                                              664.0
# 17                                              842.0
# 21                                              724.0
# 25                                              793.0
# ...                                               ...
# 2158                                            550.0
# 2169                                            985.0
# 2172                                            759.0
# 2173                                            797.0
# 2175                                            607.0
#
#       AM Mean Travel Time (Seconds)  \
# 11                            650.0
# 14                            480.0
# 17                            609.0
# 21                            489.0
# 25                            535.0
# ...                             ...
# 2158                          447.0
# 2169                          550.0
# 2172                          720.0
# 2173                          708.0
# 2175                            NaN
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 11                                           462.0  ...
# 14                                           380.0  ...
# 17                                           469.0  ...
# 21                                           376.0  ...
# 25                                           417.0  ...
# ...                                            ...  ...
# 2158                                         372.0  ...
# 2169                                         460.0  ...
# 2172                                         548.0  ...
# 2173                                         514.0  ...
# 2175                                           NaN  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 11                                          1035.0
# 14                                           677.0
# 17                                          1034.0
# 21                                           852.0
# 25                                          1002.0
# ...                                            ...
# 2158                                         642.0
# 2169                                        1327.0
# 2172                                         777.0
# 2173                                         763.0
# 2175                                         573.0
#
#       Midday Mean Travel Time (Seconds)  \
# 11                                614.0
# 14                                501.0
# 17                                657.0
# 21                                561.0
# 25                                614.0
# ...                                 ...
# 2158                              432.0
# 2169                              729.0
# 2172                              500.0
# 2173                              536.0
# 2175                              477.0
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 11                                               456.0
# 14                                               332.0
# 17                                               501.0
# 21                                               392.0
# 25                                               460.0
# ...                                                ...
# 2158                                             336.0
# 2169                                             569.0
# 2172                                             376.0
# 2173                                             394.0
# 2175                                             361.0
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 11                                               828.0
# 14                                               757.0
# 17                                               861.0
# 21                                               804.0
# 25                                               820.0
# ...                                                ...
# 2158                                             556.0
# 2169                                             934.0
# 2172                                             665.0
# 2173                                             730.0
# 2175                                             632.0
#
#       Evening Mean Travel Time (Seconds)  \
# 11                                 496.0
# 14                                 455.0
# 17                                 496.0
# 21                                 480.0
# 25                                 476.0
# ...                                  ...
# 2158                               356.0
# 2169                               405.0
# 2172                               471.0
# 2173                               405.0
# 2175                               393.0
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 11                                                357.0
# 14                                                339.0
# 17                                                368.0
# 21                                                335.0
# 25                                                339.0
# ...                                                 ...
# 2158                                              297.0
# 2169                                              313.0
# 2172                                              329.0
# 2173                                              273.0
# 2175                                              293.0
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 11                                                688.0
# 14                                                611.0
# 17                                                669.0
# 21                                                688.0
# 25                                                669.0
# ...                                                 ...
# 2158                                              427.0
# 2169                                              524.0
# 2172                                              673.0
# 2173                                              602.0
# 2175                                              525.0
#
#       Early Morning Mean Travel Time (Seconds)  \
# 11                                       417.0
# 14                                       410.0
# 17                                       408.0
# 21                                       381.0
# 25                                       423.0
# ...                                        ...
# 2158                                       NaN
# 2169                                       NaN
# 2172                                       NaN
# 2173                                     472.0
# 2175                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 11                                                331.0
# 14                                                301.0
# 17                                                312.0
# 21                                                324.0
# 25                                                317.0
# ...                                                 ...
# 2158                                                NaN
# 2169                                                NaN
# 2172                                                NaN
# 2173                                              354.0
# 2175                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 11                                                525.0
# 14                                                558.0
# 17                                                533.0
# 21                                                449.0
# 25                                                564.0
# ...                                                 ...
# 2158                                                NaN
# 2169                                                NaN
# 2172                                                NaN
# 2173                                              629.0
# 2175                                                NaN
#
# [724 rows x 23 columns]
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#             Date  Origin Movement ID                   Origin Display Name  \
# 548   05/26/2019                3394  Fisherman's Wharf, San Francisco, CA
# 554   06/09/2019                3394  Fisherman's Wharf, San Francisco, CA
# 558   04/12/2019                3394  Fisherman's Wharf, San Francisco, CA
# 567   06/17/2019                3394  Fisherman's Wharf, San Francisco, CA
# 578   04/05/2019                3394  Fisherman's Wharf, San Francisco, CA
# ...          ...                 ...                                   ...
# 3224  03/24/2019                3394  Fisherman's Wharf, San Francisco, CA
# 3225  01/28/2019                3394  Fisherman's Wharf, San Francisco, CA
# 3237  03/31/2019                3394  Fisherman's Wharf, San Francisco, CA
# 3242  01/22/2019                3394  Fisherman's Wharf, San Francisco, CA
# 3252  03/13/2019                3394  Fisherman's Wharf, San Francisco, CA
#
#       Destination Movement ID  \
# 548                      3692
# 554                      3692
# 558                      3692
# 567                      3692
# 578                      3692
# ...                       ...
# 3224                     3760
# 3225                     3760
# 3237                     3760
# 3242                     3760
# 3252                     3760
#
#                                Destination Display Name  \
# 548   2nd Street and Stevenson Street (Montgomery BA...
# 554   2nd Street and Stevenson Street (Montgomery BA...
# 558   2nd Street and Stevenson Street (Montgomery BA...
# 567   2nd Street and Stevenson Street (Montgomery BA...
# 578   2nd Street and Stevenson Street (Montgomery BA...
# ...                                                 ...
# 3224  Powell BART Station, Market St and Powell St, ...
# 3225  Powell BART Station, Market St and Powell St, ...
# 3237  Powell BART Station, Market St and Powell St, ...
# 3242  Powell BART Station, Market St and Powell St, ...
# 3252  Powell BART Station, Market St and Powell St, ...
#
#       Daily Mean Travel Time (Seconds)  \
# 548                              936.0
# 554                              907.0
# 558                              999.0
# 567                             1075.0
# 578                             1071.0
# ...                                ...
# 3224                             947.0
# 3225                             926.0
# 3237                             972.0
# 3242                            1007.0
# 3252                            1038.0
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 548                                             713.0
# 554                                             704.0
# 558                                             758.0
# 567                                             807.0
# 578                                             771.0
# ...                                               ...
# 3224                                            705.0
# 3225                                            713.0
# 3237                                            755.0
# 3242                                            714.0
# 3252                                            784.0
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 548                                            1228.0
# 554                                            1168.0
# 558                                            1316.0
# 567                                            1432.0
# 578                                            1487.0
# ...                                               ...
# 3224                                           1272.0
# 3225                                           1203.0
# 3237                                           1251.0
# 3242                                           1419.0
# 3252                                           1375.0
#
#       AM Mean Travel Time (Seconds)  \
# 548                           752.0
# 554                           703.0
# 558                          1040.0
# 567                          1113.0
# 578                          1157.0
# ...                             ...
# 3224                            NaN
# 3225                            NaN
# 3237                            NaN
# 3242                         1127.0
# 3252                         1129.0
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 548                                          604.0  ...
# 554                                          568.0  ...
# 558                                          772.0  ...
# 567                                          859.0  ...
# 578                                          828.0  ...
# ...                                            ...  ...
# 3224                                           NaN  ...
# 3225                                           NaN  ...
# 3237                                           NaN  ...
# 3242                                         892.0  ...
# 3252                                         867.0  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 548                                         1435.0
# 554                                         1480.0
# 558                                         1389.0
# 567                                         1777.0
# 578                                         1884.0
# ...                                            ...
# 3224                                        1382.0
# 3225                                           NaN
# 3237                                        1344.0
# 3242                                        1641.0
# 3252                                        1408.0
#
#       Midday Mean Travel Time (Seconds)  \
# 548                               974.0
# 554                               885.0
# 558                              1062.0
# 567                              1051.0
# 578                              1090.0
# ...                                 ...
# 3224                              962.0
# 3225                              900.0
# 3237                              970.0
# 3242                             1018.0
# 3252                             1143.0
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 548                                              775.0
# 554                                              743.0
# 558                                              868.0
# 567                                              895.0
# 578                                              846.0
# ...                                                ...
# 3224                                             686.0
# 3225                                             690.0
# 3237                                             762.0
# 3242                                             801.0
# 3252                                             875.0
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 548                                             1224.0
# 554                                             1054.0
# 558                                             1300.0
# 567                                             1235.0
# 578                                             1405.0
# ...                                                ...
# 3224                                            1347.0
# 3225                                            1172.0
# 3237                                            1235.0
# 3242                                            1294.0
# 3252                                            1493.0
#
#       Evening Mean Travel Time (Seconds)  \
# 548                                835.0
# 554                                834.0
# 558                                874.0
# 567                                886.0
# 578                                867.0
# ...                                  ...
# 3224                               879.0
# 3225                               976.0
# 3237                               906.0
# 3242                               943.0
# 3252                               942.0
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 548                                               646.0
# 554                                               693.0
# 558                                               697.0
# 567                                               746.0
# 578                                               675.0
# ...                                                 ...
# 3224                                              721.0
# 3225                                              771.0
# 3237                                              762.0
# 3242                                              760.0
# 3252                                              727.0
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 548                                              1079.0
# 554                                              1004.0
# 558                                              1097.0
# 567                                              1053.0
# 578                                              1113.0
# ...                                                 ...
# 3224                                             1071.0
# 3225                                             1236.0
# 3237                                             1076.0
# 3242                                             1171.0
# 3252                                             1221.0
#
#       Early Morning Mean Travel Time (Seconds)  \
# 548                                      841.0
# 554                                      686.0
# 558                                      660.0
# 567                                        NaN
# 578                                        NaN
# ...                                        ...
# 3224                                     716.0
# 3225                                       NaN
# 3237                                       NaN
# 3242                                       NaN
# 3252                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 548                                               663.0
# 554                                               577.0
# 558                                               514.0
# 567                                                 NaN
# 578                                                 NaN
# ...                                                 ...
# 3224                                              561.0
# 3225                                                NaN
# 3237                                                NaN
# 3242                                                NaN
# 3252                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 548                                              1066.0
# 554                                               816.0
# 558                                               848.0
# 567                                                 NaN
# 578                                                 NaN
# ...                                                 ...
# 3224                                              913.0
# 3225                                                NaN
# 3237                                                NaN
# 3242                                                NaN
# 3252                                                NaN
#
# [362 rows x 23 columns]
#             Date  Origin Movement ID                   Origin Display Name  \
# 1     04/28/2019                3603        Embarcadero, San Francisco, CA
# 2     05/18/2019                3603        Embarcadero, San Francisco, CA
# 6     04/23/2019                3603        Embarcadero, San Francisco, CA
# 7     05/13/2019                3603        Embarcadero, San Francisco, CA
# 22    05/11/2019                3603        Embarcadero, San Francisco, CA
# ...          ...                 ...                                   ...
# 2155  03/10/2019                3603  Fisherman's Wharf, San Francisco, CA
# 2157  03/19/2019                3603  Fisherman's Wharf, San Francisco, CA
# 2163  03/04/2019                3603  Fisherman's Wharf, San Francisco, CA
# 2171  02/05/2019                3603  Fisherman's Wharf, San Francisco, CA
# 2176  02/24/2019                3603  Fisherman's Wharf, San Francisco, CA
#
#       Destination Movement ID              Destination Display Name  \
# 1                        3394  Fisherman's Wharf, San Francisco, CA
# 2                        3394  Fisherman's Wharf, San Francisco, CA
# 6                        3394  Fisherman's Wharf, San Francisco, CA
# 7                        3394  Fisherman's Wharf, San Francisco, CA
# 22                       3394  Fisherman's Wharf, San Francisco, CA
# ...                       ...                                   ...
# 2155                     3394        Embarcadero, San Francisco, CA
# 2157                     3394        Embarcadero, San Francisco, CA
# 2163                     3394        Embarcadero, San Francisco, CA
# 2171                     3394        Embarcadero, San Francisco, CA
# 2176                     3394        Embarcadero, San Francisco, CA
#
#       Daily Mean Travel Time (Seconds)  \
# 1                                639.0
# 2                                730.0
# 6                                682.0
# 7                                634.0
# 22                               670.0
# ...                                ...
# 2155                             680.0
# 2157                             757.0
# 2163                             668.0
# 2171                             704.0
# 2176                             721.0
#
#       Daily Range - Lower Bound Travel Time (Seconds)  \
# 1                                               512.0
# 2                                               520.0
# 6                                               500.0
# 7                                               457.0
# 22                                              509.0
# ...                                               ...
# 2155                                            527.0
# 2157                                            524.0
# 2163                                            533.0
# 2171                                            542.0
# 2176                                            569.0
#
#       Daily Range - Upper Bound Travel Time (Seconds)  \
# 1                                               796.0
# 2                                              1024.0
# 6                                               931.0
# 7                                               878.0
# 22                                              881.0
# ...                                               ...
# 2155                                            876.0
# 2157                                           1095.0
# 2163                                            837.0
# 2171                                            915.0
# 2176                                            914.0
#
#       AM Mean Travel Time (Seconds)  \
# 1                               NaN
# 2                               NaN
# 6                               NaN
# 7                               NaN
# 22                            601.0
# ...                             ...
# 2155                            NaN
# 2157                          875.0
# 2163                          762.0
# 2171                          879.0
# 2176                            NaN
#
#       AM Range - Lower Bound Travel Time (Seconds)  ...  \
# 1                                              NaN  ...
# 2                                              NaN  ...
# 6                                              NaN  ...
# 7                                              NaN  ...
# 22                                           509.0  ...
# ...                                            ...  ...
# 2155                                           NaN  ...
# 2157                                         633.0  ...
# 2163                                         599.0  ...
# 2171                                         708.0  ...
# 2176                                           NaN  ...
#
#       PM Range - Upper Bound Travel Time (Seconds)  \
# 1                                            793.0
# 2                                            985.0
# 6                                            949.0
# 7                                            893.0
# 22                                           773.0
# ...                                            ...
# 2155                                         907.0
# 2157                                        1260.0
# 2163                                         781.0
# 2171                                         932.0
# 2176                                         963.0
#
#       Midday Mean Travel Time (Seconds)  \
# 1                                 654.0
# 2                                 791.0
# 6                                 756.0
# 7                                 584.0
# 22                                736.0
# ...                                 ...
# 2155                              698.0
# 2157                              731.0
# 2163                              620.0
# 2171                              667.0
# 2176                              724.0
#
#       Midday Range - Lower Bound Travel Time (Seconds)  \
# 1                                                524.0
# 2                                                590.0
# 6                                                577.0
# 7                                                470.0
# 22                                               557.0
# ...                                                ...
# 2155                                             517.0
# 2157                                             587.0
# 2163                                             519.0
# 2171                                             556.0
# 2176                                             611.0
#
#       Midday Range - Upper Bound Travel Time (Seconds)  \
# 1                                                817.0
# 2                                               1061.0
# 6                                                991.0
# 7                                                726.0
# 22                                               973.0
# ...                                                ...
# 2155                                             943.0
# 2157                                             911.0
# 2163                                             741.0
# 2171                                             800.0
# 2176                                             858.0
#
#       Evening Mean Travel Time (Seconds)  \
# 1                                  608.0
# 2                                  569.0
# 6                                  550.0
# 7                                  611.0
# 22                                 540.0
# ...                                  ...
# 2155                               588.0
# 2157                               709.0
# 2163                               659.0
# 2171                               722.0
# 2176                               700.0
#
#       Evening Range - Lower Bound Travel Time (Seconds)  \
# 1                                                 492.0
# 2                                                 406.0
# 6                                                 406.0
# 7                                                 424.0
# 22                                                424.0
# ...                                                 ...
# 2155                                              487.0
# 2157                                              500.0
# 2163                                              493.0
# 2171                                              631.0
# 2176                                              581.0
#
#       Evening Range - Upper Bound Travel Time (Seconds)  \
# 1                                                 753.0
# 2                                                 797.0
# 6                                                 745.0
# 7                                                 880.0
# 22                                                688.0
# ...                                                 ...
# 2155                                              710.0
# 2157                                             1005.0
# 2163                                              881.0
# 2171                                              826.0
# 2176                                              843.0
#
#       Early Morning Mean Travel Time (Seconds)  \
# 1                                          NaN
# 2                                          NaN
# 6                                          NaN
# 7                                          NaN
# 22                                         NaN
# ...                                        ...
# 2155                                       NaN
# 2157                                       NaN
# 2163                                       NaN
# 2171                                       NaN
# 2176                                       NaN
#
#       Early Morning Range - Lower Bound Travel Time (Seconds)  \
# 1                                                   NaN
# 2                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 22                                                  NaN
# ...                                                 ...
# 2155                                                NaN
# 2157                                                NaN
# 2163                                                NaN
# 2171                                                NaN
# 2176                                                NaN
#
#       Early Morning Range - Upper Bound Travel Time (Seconds)
# 1                                                   NaN
# 2                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 22                                                  NaN
# ...                                                 ...
# 2155                                                NaN
# 2157                                                NaN
# 2163                                                NaN
# 2171                                                NaN
# 2176                                                NaN
#
# [724 rows x 23 columns]

# %%
import seaborn as sns 
def make_boxplot(df):
    ax = sns.boxplot(x='Destination Movement ID', y='Daily Mean Travel Time (Seconds)',
                     data= df, palette="Set3")
    return ax

# %%
import seaborn as sns 
ax = sns.boxplot(x='Destination Movement ID', y='Daily Mean Travel Time (Seconds)',
                 data=bh_hotspots_3396, palette="Set3")
ax

# %%
b = make_boxplot(bh_hotspots_3792)
b

# %%
c = make_boxplot(bh_hotspots_3394)
c
