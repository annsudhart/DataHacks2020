# %%
import pandas as pd
import seaborn as sns
from datetime import datetime

# %%
bh_data = pd.read_csv('datasets/barts_hotspots.csv');
ba_data = pd.read_csv('datasets/barts_to_all.csv');
ha_data = pd.read_csv('datasets/hotspots_to_all.csv');
h1_data = pd.read_csv('datasets/hours_q1.csv');
h2_data = pd.read_csv('datasets/hours_q2.csv');

# %%
ba_data.head(5) #original dataframe
ba_df = ba_data
ba_df['Mean Travel Time (Minutes)'] = ba_df['Mean Travel Time (Seconds)']/60
ba_df['Range - Lower Bound Travel Time (Minutes)'] = ba_df['Range - Lower Bound Travel Time (Seconds)']/60
ba_df['Range - Upper Bound Travel Time (Minutes)'] = ba_df['Range - Upper Bound Travel Time (Seconds)']/60
ba_df['Range(Minutes)'] = ba_df['Range - Upper Bound Travel Time (Minutes)'] - ba_df['Range - Lower Bound Travel Time (Minutes)']
ba_df.head(5)
# Out:
#    Origin Movement ID             Origin Display Name  \
# 0                3603  Embarcadero, San Francisco, CA
# 1                3603  Embarcadero, San Francisco, CA
# 2                3603  Embarcadero, San Francisco, CA
# 3                3603  Embarcadero, San Francisco, CA
# 4                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID Destination Display Name  \
# 0                     1987            709716 (1987)
# 1                     1994            910502 (1994)
# 2                     2020            609301 (2020)
# 3                     2044            609270 (2044)
# 4                     2054            609261 (2054)
#
#                                        Date Range  Mean Travel Time (Seconds)  \
# 0  4/1/2019 - 6/30/2019, Every day, Daily Average                        3373
# 1  4/1/2019 - 6/30/2019, Every day, Daily Average                        2888
# 2  4/1/2019 - 6/30/2019, Every day, Daily Average                        3015
# ...

# %%
ha_data['Mean Travel Time (Minutes)'] = ba_df['Mean Travel Time (Seconds)']/60
ha_data['Range - Lower Bound Travel Time (Minutes)'] = ba_df['Range - Lower Bound Travel Time (Seconds)']/60
ba_df['Range - Upper Bound Travel Time (Minutes)'] = ba_df['Range - Upper Bound Travel Time (Seconds)']/60
ba_df['Range(Minutes)'] = ba_df['Range - Upper Bound Travel Time (Minutes)'] - ba_df['Range - Lower Bound Travel Time (Minutes)']
ha_data.head(10)
# Out:
#    Origin Movement ID                   Origin Display Name  \
# 0                3394  Fisherman's Wharf, San Francisco, CA
# 1                3394  Fisherman's Wharf, San Francisco, CA
# 2                3394  Fisherman's Wharf, San Francisco, CA
# 3                3394  Fisherman's Wharf, San Francisco, CA
# 4                3394  Fisherman's Wharf, San Francisco, CA
# 5                3394  Fisherman's Wharf, San Francisco, CA
# 6                3394  Fisherman's Wharf, San Francisco, CA
# 7                3394  Fisherman's Wharf, San Francisco, CA
# 8                3394  Fisherman's Wharf, San Francisco, CA
# 9                3394  Fisherman's Wharf, San Francisco, CA
#
#    Destination Movement ID Destination Display Name  \
# 0                     1608            709746 (1608)
# 1                     1803            809911 (1803)
# 2                     1845            910670 (1845)
# 3                     1864            709739 (1864)
# ...

# %%
h1_data.head(10)
# Out:
#    sourceid  dstid  hod  mean_travel_time  standard_deviation_travel_time  \
# 0      3768   3700    3            161.58                           87.83
# 1      3772   3660    3            373.98                          217.24
# 2      3751   3708    6           1197.27                          259.18
# 3      3761   3608    6            588.32                          223.30
# 4      3767   3724   17            438.98                          235.70
# 5      3778   3614   17           1771.23                          439.96
# 6      3769   3704   17            511.86                          270.83
# 7      3775   3644   17            544.15                          228.36
# 8      3772   3674   17            963.83                          504.70
# 9      3779   3604   17            501.38                          176.70
#
#    geometric_mean_travel_time  geometric_standard_deviation_travel_time
# 0                      147.02                                      1.49
# ...

# %%
h2_data.head(10)
# Out:
#    sourceid  dstid  hod  mean_travel_time  standard_deviation_travel_time  \
# 0      3709   3671   13            875.06                          232.37
# 1      3708   3681   13            850.12                          224.94
# 2      3632   3715    8           1017.34                          298.82
# 3      3642   3615    8             94.17                           75.18
# 4      3643   3605    8            171.74                          205.52
# 5      3633   3705    8           1037.53                          395.25
# 6      3641   3625    8            829.87                          219.15
# 7      3640   3635    8           1955.09                         1595.53
# 8      3647   3722   15            503.34                          325.88
# 9      3644   3752   15            869.55                          273.24
#
#    geometric_mean_travel_time  geometric_standard_deviation_travel_time
# 0                      850.74                                      1.25
# ...

# %%
bh_data = pd.read_csv('datasets/barts_hotspots.csv');
bh_df = bh_data
# datetime.strptime(bh_df['Date'][0], '%m/%d/%Y').weekday()
dow_index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
bh_df['dow'] = bh_df['Date'].apply(lambda x : dow_index[datetime.strptime(x, '%m/%d/%Y').weekday()])
bh_df
# Out:
#             Date  Origin Movement ID  \
# 0     06/09/2019                3396
# 1     04/28/2019                3603
# 2     05/18/2019                3603
# 3     04/18/2019                3792
# 4     04/08/2019                3792
# 5     06/30/2019                3792
# 6     04/23/2019                3603
# 7     05/13/2019                3603
# 8     05/15/2019                3394
# 9     04/14/2019                3603
# 10    06/01/2019                3394
# 11    04/18/2019                3603
# 12    06/11/2019                3792
# 13    05/29/2019                3394
# 14    04/21/2019                3603
# 15    06/06/2019                3396
# 16    04/18/2019                3396
# 17    05/16/2019                3603
# 18    06/11/2019                3396
# 19    05/07/2019                3394
# 20    05/01/2019                3792
# 21    04/27/2019                3603
# 22    05/11/2019                3603
# 23    04/25/2019                3603
# ...

# %%
h1 = bh_data[((bh_data['Origin Movement ID'] ==3396) | (bh_data['Origin Movement ID'] ==3396))]
h2 = bh_data[((bh_data['Origin Movement ID'] ==3394) | (bh_data['Origin Movement ID'] ==3394))]
h3 = bh_data[((bh_data['Origin Movement ID'] ==3792) | (bh_data['Origin Movement ID'] ==3792))]

# %%
a = h1.boxplot(column=['Daily Mean Travel Time (Seconds)',
       #'Daily Range - Lower Bound Travel Time (Seconds)',
       #'Daily Range - Upper Bound Travel Time (Seconds)',
       'AM Mean Travel Time (Seconds)',
       #'AM Range - Lower Bound Travel Time (Seconds)',
       #'AM Range - Upper Bound Travel Time (Seconds)',
       'PM Mean Travel Time (Seconds)',
       #'PM Range - Lower Bound Travel Time (Seconds)',
       #'PM Range - Upper Bound Travel Time (Seconds)',
       'Midday Mean Travel Time (Seconds)',
       #'Midday Range - Lower Bound Travel Time (Seconds)',
       #'Midday Range - Upper Bound Travel Time (Seconds)',
       'Evening Mean Travel Time (Seconds)',
       #'Evening Range - Lower Bound Travel Time (Seconds)',
       #'Evening Range - Upper Bound Travel Time (Seconds)',
       'Early Morning Mean Travel Time (Seconds)',
       #'Early Morning Range - Lower Bound Travel Time (Seconds)',
       #'Early Morning Range - Upper Bound Travel Time (Seconds)']
                                    ],figsize = (10,8),rot=90)
a.set_ylabel("Travel Time (Seconds)")
a.set_title("")
a

# %%
h1
# Out:
#             Date  Origin Movement ID  \
# 0     06/09/2019                3396
# 15    06/06/2019                3396
# 16    04/18/2019                3396
# 18    06/11/2019                3396
# 30    05/03/2019                3396
# 42    04/12/2019                3396
# 51    04/01/2019                3396
# 53    06/07/2019                3396
# 58    05/13/2019                3396
# 63    05/26/2019                3396
# 64    06/18/2019                3396
# 81    04/09/2019                3396
# 83    05/15/2019                3396
# 87    06/03/2019                3396
# 95    05/17/2019                3396
# 97    06/23/2019                3396
# 102   04/21/2019                3396
# 111   05/10/2019                3396
# 113   04/14/2019                3396
# 128   05/14/2019                3396
# 134   06/27/2019                3396
# 138   06/25/2019                3396
# 139   05/02/2019                3396
# 152   04/23/2019                3396
# ...

# %%
h1_3396 = h1[(h1['Origin Movement ID'] == 3396)]
h1_3396
# Out:
#             Date  Origin Movement ID  \
# 0     06/09/2019                3396
# 15    06/06/2019                3396
# 16    04/18/2019                3396
# 18    06/11/2019                3396
# 30    05/03/2019                3396
# 42    04/12/2019                3396
# 51    04/01/2019                3396
# 53    06/07/2019                3396
# 58    05/13/2019                3396
# 63    05/26/2019                3396
# 64    06/18/2019                3396
# 81    04/09/2019                3396
# 83    05/15/2019                3396
# 87    06/03/2019                3396
# 95    05/17/2019                3396
# 97    06/23/2019                3396
# 102   04/21/2019                3396
# 111   05/10/2019                3396
# 113   04/14/2019                3396
# 128   05/14/2019                3396
# 134   06/27/2019                3396
# 138   06/25/2019                3396
# 139   05/02/2019                3396
# 152   04/23/2019                3396
# ...

# %%
sns.set(style='ticks')

tips = sns.load_dataset('datasets/barts_hotspots.csv')

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x=h1_3396['', y="total_bill",
            hue="smoker",
            data=tips)
sns.despine(offset=10, trim=True)
